# %%
import pandas as pd
import numpy as np
from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded['ExportCSV (4).csv']))
# Out:
#      <input type="file" id="files-5dec6827-b2f1-475e-bf73-cf739c7b56e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5dec6827-b2f1-475e-bf73-cf739c7b56e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df
# Out:
#        ID               Job Title                  Email Address  \
# 0       1                  Banker    Aiden_Dowson5987@famism.biz
# 1       2                 Steward   Harmony_Ripley6833@vetan.org
# 2       3       Software Engineer        Josh_Khan399@iatim.tech
# 3       4  Front Desk Coordinator    Bree_Oliver4051@ubusive.com
# 4       5      Executive Director      Josh_Walsh3730@kideod.biz
# ...   ...                     ...                            ...
# 1021  956                   Clerk       Penny_Shaw6590@gmail.com
# 1022  957      Restaurant Manager        Fred_Grady934@zorer.org
# 1023  958       Software Engineer    Clint_Ingham4221@sveldo.biz
# 1024  959     Staffing Consultant       Norah_Roth6634@deavo.com
# 1025  960                 Bellman  Shay_Blackwall7035@famism.biz
#
#      FirstName LastName                              Education  Gender  \
# 0          Aiden Dowson              The Ohio State University    Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1026 entries, 0 to 1025
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  1026 non-null   int64
#  1   Job Title           1026 non-null   object
#  2   Email Address       1026 non-null   object
#  3   FirstName LastName  1026 non-null   object
#  4   Education           1026 non-null   object
#  5   Gender              1026 non-null   object
#  6   Born Date           1026 non-null   object
#  7   Bank Account        1026 non-null   object
#  8   Job Skill           1026 non-null   object
#  9   Country             1026 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 80.3+ KB

# %%
df1= df.set_index('ID')
df1.iloc[[1],:]
# Out:
#    Job Title                 Email Address FirstName LastName  \
# ID
# 2    Steward  Harmony_Ripley6833@vetan.org     Harmony Ripley
#
#                         Education  Gender                 Born Date  \
# ID
# 2   Pennsylvania State University  Female  Thursday, April 15, 2021
#
#       Bank Account            Job Skill  Country
# ID
# 2   670,880,650MOP  Conflict Resolution  Algeria

# %%
df1.loc[[300]]
# Out:
#     Job Title                    Email Address FirstName LastName  \
# ID
# 300     Clerk  Shannon_Johnson7398@joiniaa.com    Shannon Johnson
#
#                        Education  Gender                 Born Date  \
# ID
# 300  University of South Florida  Female  Monday, February 7, 2022
#
#        Bank Account        Job Skill Country
# ID
# 300  902,383,341XOF  Time Management  Cyprus

# %%
df.groupby(['Gender', 'Country']).count()
# Out:
#                     ID  Job Title  Email Address  FirstName LastName  \
# Gender Country
# Female Afghanistan   3          3              3                   3
#        Albania       3          3              3                   3
#        Algeria       4          4              4                   4
#        Andorra       4          4              4                   4
#        Angola        1          1              1                   1
# ...                 ..        ...            ...                 ...
# Male   Venezuela     1          1              1                   1
#        Vietnam       3          3              3                   3
#        Yemen         2          2              2                   2
#        Zambia        3          3              3                   3
#        Zimbabwe      1          1              1                   1
#
#                     Education  Born Date  Bank Account  Job Skill
# Gender Country
# ...

# %%
df[df['ID']>999]
# Out:
#         ID         Job Title                  Email Address  \
# 999   1000  Mobile Developer  Alessandra_Kidd4049@sheye.org
# 1012  1000  Mobile Developer  Alessandra_Kidd4049@sheye.org
#
#      FirstName LastName                             Education  Gender  \
# 999     Alessandra Kidd  Massachusets Institute of Technology  Female
# 1012    Alessandra Kidd  Massachusets Institute of Technology  Female
#
#                         Born Date    Bank Account            Job Skill  \
# 999   Thursday, December 30, 2021  822,123,937BSD  Work Under Pressure
# 1012  Thursday, December 30, 2021  822,123,937BSD  Work Under Pressure
#
#       Country
# 999   Croatia
# 1012  Croatia

# %%
#df[df['Country'] =='Croatia' & df['FirstName LastName'].str.countains('Kidd')]
df[(df['Country'] == 'Croatia') & df['FirstName LastName'].str.contains('Kidd')]
# Out:
#         ID         Job Title                  Email Address  \
# 999   1000  Mobile Developer  Alessandra_Kidd4049@sheye.org
# 1012  1000  Mobile Developer  Alessandra_Kidd4049@sheye.org
#
#      FirstName LastName                             Education  Gender  \
# 999     Alessandra Kidd  Massachusets Institute of Technology  Female
# 1012    Alessandra Kidd  Massachusets Institute of Technology  Female
#
#                         Born Date    Bank Account            Job Skill  \
# 999   Thursday, December 30, 2021  822,123,937BSD  Work Under Pressure
# 1012  Thursday, December 30, 2021  822,123,937BSD  Work Under Pressure
#
#       Country
# 999   Croatia
# 1012  Croatia

# %%
df
# Out:
#        ID               Job Title                  Email Address  \
# 0       1                  Banker    Aiden_Dowson5987@famism.biz
# 1       2                 Steward   Harmony_Ripley6833@vetan.org
# 2       3       Software Engineer        Josh_Khan399@iatim.tech
# 3       4  Front Desk Coordinator    Bree_Oliver4051@ubusive.com
# 4       5      Executive Director      Josh_Walsh3730@kideod.biz
# ...   ...                     ...                            ...
# 1021  956                   Clerk       Penny_Shaw6590@gmail.com
# 1022  957      Restaurant Manager        Fred_Grady934@zorer.org
# 1023  958       Software Engineer    Clint_Ingham4221@sveldo.biz
# 1024  959     Staffing Consultant       Norah_Roth6634@deavo.com
# 1025  960                 Bellman  Shay_Blackwall7035@famism.biz
#
#      FirstName LastName                              Education  Gender  \
# 0          Aiden Dowson              The Ohio State University    Male
# ...

# %%
df[(df['ID'] > 500) & df['FirstName LastName'].str.contains('Al')]
# Out:
#         ID            Job Title                     Email Address  \
# 537    538  Staffing Consultant         Alan_Lynch1610@twipet.com
# 694    695       Budget Analyst         Ally_Dunbar7974@gmail.com
# 711    712      Assistant Buyer      Louise_Alcroft4611@zorer.org
# 786    787             Lecturer   Julia_Alexander7483@ubusive.com
# 820    821                 Cook    Alexa_Wooldridge8399@qater.org
# 840    841           Pharmacist       Bob_Allwood6103@ubusive.com
# 869    870     Mobile Developer        Allison_Hogg157@deons.tech
# 883    884   Restaurant Manager         Alex_Potter7085@brety.org
# 890    891      Business Broker        Alexa_Mcleod5275@extex.org
# 894    895    Food Technologist  Aleksandra_Wilton8649@elnee.tech
# 932    933        Web Developer      Raquel_Alcroft3081@brety.org
# 960    961     Ambulatory Nurse    Alexander_Reyes1387@ovock.tech
# 968    969      Business Broker  Rebecca_Alexander663@irrepsy.com
# ...

# %%
# df[(df['Country'] == 'Croatia' )| (df['Country'] == 'Barbados' & df['FirstName LastName'].str.contains('Ale'))]

# %%
df[(df['Country'] == 'Croatia') | ((df['Country'] == 'Barbados') & df['FirstName LastName'].str.contains('Ale'))]
# Out:
#         ID           Job Title                     Email Address  \
# 329    330               Clerk         Carl_Snell7644@muall.tech
# 358    359           Treasurer        Jules_Blythe4340@brety.org
# 481    482  Restaurant Manager       Agnes_Gilbert4763@acrit.org
# 545    546  Restaurant Manager         Fred_Hobson8684@deavo.com
# 559    560          Pharmacist         Barry_Abbey7029@tonsy.org
# 601    602            Lecturer        Aiden_Addis7065@nimogy.biz
# 616    617     Project Manager      Julius_Wright4305@ovock.tech
# 699    700           Treasurer      Ronald_Dowson4854@mafthy.com
# 839    840     Health Educator       Chuck_Holmes6896@mafthy.com
# 968    969     Business Broker  Rebecca_Alexander663@irrepsy.com
# 973    974        Cash Manager      Stella_Connell5583@corti.com
# 999   1000    Mobile Developer     Alessandra_Kidd4049@sheye.org
# 1012  1000    Mobile Developer     Alessandra_Kidd4049@sheye.org
#
# ...

# %%
df.mode()
# Out:
#         ID     Job Title                     Email Address FirstName LastName  \
# 0    948.0  Loan Officer       Abdul_Gregory4897@liret.org      Abdul Gregory
# 1    949.0           NaN        Adina_Abbot329@grannar.com        Adina Abbot
# 2    950.0           NaN     Alessandra_Kidd4049@sheye.org    Alessandra Kidd
# 3    951.0           NaN  Angelique_Webster7085@guentu.biz  Angelique Webster
# 4    952.0           NaN       Anthony_Price7578@vetan.org      Anthony Price
# 5    953.0           NaN        Boris_Ellery7603@qater.org       Boris Ellery
# 6    954.0           NaN      Carolyn_Ingham9610@liret.org     Carolyn Ingham
# 7    955.0           NaN     Chuck_Cavanagh2796@nickia.com     Chuck Cavanagh
# 8    956.0           NaN       Clint_Ingham4221@sveldo.biz       Clint Ingham
# 9    957.0           NaN       Elijah_Bailey2485@brety.org      Elijah Bailey
# 10   958.0           NaN           Fred_Grady934@zorer.org         Fred Grady
# ...

# %%
df['Country'].value_counts().max()
# Out:
# 13

# %%
df.isna().value_counts()
# Out:
# ID     Job Title  Email Address  FirstName LastName  Education  Gender  Born Date  Bank Account  Job Skill  Country
# False  False      False          False               False      False   False      False         False      False      1026
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#        ID               Job Title                  Email Address  \
# 0       1                  Banker    Aiden_Dowson5987@famism.biz
# 1       2                 Steward   Harmony_Ripley6833@vetan.org
# 2       3       Software Engineer        Josh_Khan399@iatim.tech
# 3       4  Front Desk Coordinator    Bree_Oliver4051@ubusive.com
# 4       5      Executive Director      Josh_Walsh3730@kideod.biz
# ..    ...                     ...                            ...
# 995   996   Systems Administrator    Shelby_Brown7385@bungar.biz
# 996   997        IT Support Staff     Leilani_Cobb6337@tonsy.org
# 997   998            CNC Operator    Matt_Lambert3109@nimogy.biz
# 998   999               Treasurer    Anthony_Price7578@vetan.org
# 999  1000        Mobile Developer  Alessandra_Kidd4049@sheye.org
#
#     FirstName LastName                              Education  Gender  \
# 0         Aiden Dowson              The Ohio State University    Male
# ...

# %%
#df[['Country','FirstName LastName','Bank Account']].groupby('Country')
df[['Country', 'FirstName LastName', 'Bank Account']].groupby('Country').count()
# Out:
#              FirstName LastName  Bank Account
# Country
# Afghanistan                   5             5
# Albania                       6             6
# Algeria                       6             6
# Andorra                       7             7
# Angola                        4             4
# ...                         ...           ...
# Venezuela                     5             5
# Vietnam                       5             5
# Yemen                         8             8
# Zambia                        5             5
# Zimbabwe                      4             4
#
# [194 rows x 2 columns]

# %%
df[(df['ID'] > 50) & (df['ID']< 60)]
# Out:
#     ID        Job Title                    Email Address FirstName LastName  \
# 50  51  Business Broker     Chad_Richards7621@supunk.biz      Chad Richards
# 51  52     Loan Officer  Melinda_Dickson1734@ubusive.com    Melinda Dickson
# 52  53         Designer   Rosalee_Chapman5798@supunk.biz    Rosalee Chapman
# 53  54         Operator     Maxwell_Mcleod9749@sheye.org     Maxwell Mcleod
# 54  55         Operator    Rufus_Everett9185@womeona.net      Rufus Everett
# 55  56          Steward      Regina_Holt1414@joiniaa.com        Regina Holt
# 56  57          Bellman      Diane_Lomax5307@bretoux.com        Diane Lomax
# 57  58  Assistant Buyer      Hadley_Ralph1273@elnee.tech       Hadley Ralph
# 58  59        Webmaster        Anthony_Fox6070@sheye.org        Anthony Fox
#
#                                             Education  Gender  \
# 50                          The University of Georgia    Male
# 51                             University of Michigan  Female
# ...

# %%
df.query('ID > 50 and ID < 60')
# Out:
#     ID        Job Title                    Email Address FirstName LastName  \
# 50  51  Business Broker     Chad_Richards7621@supunk.biz      Chad Richards
# 51  52     Loan Officer  Melinda_Dickson1734@ubusive.com    Melinda Dickson
# 52  53         Designer   Rosalee_Chapman5798@supunk.biz    Rosalee Chapman
# 53  54         Operator     Maxwell_Mcleod9749@sheye.org     Maxwell Mcleod
# 54  55         Operator    Rufus_Everett9185@womeona.net      Rufus Everett
# 55  56          Steward      Regina_Holt1414@joiniaa.com        Regina Holt
# 56  57          Bellman      Diane_Lomax5307@bretoux.com        Diane Lomax
# 57  58  Assistant Buyer      Hadley_Ralph1273@elnee.tech       Hadley Ralph
# 58  59        Webmaster        Anthony_Fox6070@sheye.org        Anthony Fox
#
#                                             Education  Gender  \
# 50                          The University of Georgia    Male
# 51                             University of Michigan  Female
# ...

# %%
df[df['ID'].between(50,60)]
# Out:
#     ID              Job Title                     Email Address  \
# 49  50  Systems Administrator  Johnny_Whitehouse8400@bauros.biz
# 50  51        Business Broker      Chad_Richards7621@supunk.biz
# 51  52           Loan Officer   Melinda_Dickson1734@ubusive.com
# 52  53               Designer    Rosalee_Chapman5798@supunk.biz
# 53  54               Operator      Maxwell_Mcleod9749@sheye.org
# 54  55               Operator     Rufus_Everett9185@womeona.net
# 55  56                Steward       Regina_Holt1414@joiniaa.com
# 56  57                Bellman       Diane_Lomax5307@bretoux.com
# 57  58        Assistant Buyer       Hadley_Ralph1273@elnee.tech
# 58  59              Webmaster         Anthony_Fox6070@sheye.org
# 59  60              Biologist    Dakota_Thornton3486@mafthy.com
#
#    FirstName LastName                                          Education  \
# 49  Johnny Whitehouse                                  Lehigh University
# ...

# %%
df.sort_values(['FirstName LastName','Bank Account'], ascending = False)
# Out:
#        ID           Job Title                Email Address FirstName LastName  \
# 841   842             Cashier       Zoe_Cann2175@acrit.org           Zoe Cann
# 675   676  Service Supervisor   Zara_Redwood9601@vetan.org       Zara Redwood
# 69     70       HR Specialist    Zara_King7459@bulaffy.com          Zara King
# 212   213           Biologist       Zara_Cox5364@liret.org           Zara Cox
# 217   218     Assistant Buyer  Zara_Anderson9261@yahoo.com      Zara Anderson
# ...   ...                 ...                          ...                ...
# 375   376         Electrician   Abdul_Lewin8713@mafthy.com        Abdul Lewin
# 993   994     Health Educator  Abdul_Gregory4897@liret.org      Abdul Gregory
# 1006  994     Health Educator  Abdul_Gregory4897@liret.org      Abdul Gregory
# 8       9            Operator  Abdul_Dickson1496@extex.org      Abdul Dickson
# 795   796  Service Supervisor   Abbey_Tanner1871@yahoo.com       Abbey Tanner
#
# ...

# %%
import requests
import json

# %%
url = 'https://www.fruityvice.com/api/fruit/all'

# %%
r = requests.get(url)
data = r.json()

# %%
r
# Out:
# <Response [200]>

# %%
json = r.json()

# %%
json

# %%
df = pd.DataFrame(data)

# %%
df

# %%
df.head(10)
# Out:
#           name  id         family             order      genus  \
# 0    Persimmon  52      Ebenaceae           Rosales  Diospyros
# 1   Strawberry   3       Rosaceae           Rosales   Fragaria
# 2       Banana   1       Musaceae      Zingiberales       Musa
# 3       Tomato   5     Solanaceae         Solanales    Solanum
# 4         Pear   4       Rosaceae           Rosales      Pyrus
# 5       Durian  60      Malvaceae          Malvales      Durio
# 6   Blackberry  64       Rosaceae           Rosales      Rubus
# 7  Lingonberry  65      Ericaceae          Ericales  Vaccinium
# 8         Kiwi  66  Actinidiaceae  Struthioniformes    Apteryx
# 9       Lychee  67    Sapindaceae        Sapindales     Litchi
#
#                                           nutritions
# 0  {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2  {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3  {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# ...

# %%
#1
df[['name','family']].groupby('family').count()

# %%
#2
df[['name','genus']].groupby('genus').count()

# %%
df['nutritions']
# Out:
# 0     {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1     {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2     {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3     {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# 4     {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'c...
# 5     {'calories': 147, 'fat': 5.3, 'sugar': 6.75, '...
# 6     {'calories': 40, 'fat': 0.4, 'sugar': 4.5, 'ca...
# 7     {'calories': 50, 'fat': 0.34, 'sugar': 5.74, '...
# 8     {'calories': 61, 'fat': 0.5, 'sugar': 9.0, 'ca...
# 9     {'calories': 66, 'fat': 0.44, 'sugar': 15.0, '...
# 10    {'calories': 50, 'fat': 0.12, 'sugar': 9.85, '...
# 11    {'calories': 74, 'fat': 0.3, 'sugar': 16.0, 'c...
# 12    {'calories': 44, 'fat': 0.6, 'sugar': 0.0, 'ca...
# 13    {'calories': 97, 'fat': 0.7, 'sugar': 11.2, 'c...
# 14    {'calories': 46, 'fat': 0.28, 'sugar': 9.92, '...
# 15    {'calories': 43, 'fat': 0.2, 'sugar': 8.2, 'ca...
# 16    {'calories': 21, 'fat': 0.1, 'sugar': 6.4, 'ca...
# ...

# %%
#3
filtered_df = df[df['nutritions'].apply(lambda x: x['calories'] <30)]
filtered_df
# Out:
#           name  id    family       order     genus  \
# 1   Strawberry   3  Rosaceae     Rosales  Fragaria
# 16  GreenApple  72  Rosaceae     Rosales     Malus
# 19       Lemon  26  Rutaceae  Sapindales    Citrus
# 21   Blueberry  33  Rosaceae     Rosales  Fragaria
# 24     Apricot  35  Rosaceae     Rosales    Prunus
# 29        Lime  44  Rutaceae  Sapindales    Citrus
#
#                                            nutritions
# 1   {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 16  {'calories': 21, 'fat': 0.1, 'sugar': 6.4, 'ca...
# 19  {'calories': 29, 'fat': 0.3, 'sugar': 2.5, 'ca...
# 21  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 24  {'calories': 15, 'fat': 0.1, 'sugar': 3.2, 'ca...
# 29  {'calories': 25, 'fat': 0.1, 'sugar': 1.7, 'ca...

# %%
df['genus'].sort_values()
# Out:
# 36       Actinidia
# 10          Ananas
# 8          Apteryx
# 28       Cactaceae
# 25          Carica
# 18       Citrullus
# 19          Citrus
# 29          Citrus
# 27          Citrus
# 15          Citrus
# 26         Cucumis
# 0        Diospyros
# 5            Durio
# 11           Ficus
# 21        Fragaria
# 1         Fragaria
# 9           Litchi
# 16           Malus
# 22           Malus
# 20       Mangifera
# 33           Morus
# 2             Musa
# 13      Passiflora
# 35          Persea
# 39          Prunus
# 38          Prunus
# 14          Prunus
# 24          Prunus
# 23         Psidium
# 30          Punica
# 4            Pyrus
# 12           Ribes
# 17           Rubus
# 6            Rubus
# 31    Selenicereus
# 34      Sellowiana
# 3          Solanum
# 7        Vaccinium
# 37       Vaccinium
# 32           Vitis
# Name: genus, dtype: object

# %%
#4
filtered_df1 = df[df['nutritions'].apply(lambda x: x['sugar'] <1 )]
filtered_df1
# Out:
#           name  id           family         order   genus  \
# 12  Gooseberry  69  Grossulariaceae  Saxifragales   Ribes
# 35     Avocado  84        Lauraceae      Laurales  Persea
#
#                                            nutritions
# 12  {'calories': 44, 'fat': 0.6, 'sugar': 0.0, 'ca...
# 35  {'calories': 160, 'fat': 14.66, 'sugar': 0.66,...

# %%
#4.1
filtered_df1[(filtered_df1['genus'] == 'Ribes') | (filtered_df1['genus'] == 'Persea')]
# Out:
#           name  id           family         order   genus  \
# 12  Gooseberry  69  Grossulariaceae  Saxifragales   Ribes
# 35     Avocado  84        Lauraceae      Laurales  Persea
#
#                                            nutritions
# 12  {'calories': 44, 'fat': 0.6, 'sugar': 0.0, 'ca...
# 35  {'calories': 160, 'fat': 14.66, 'sugar': 0.66,...

# %%
new_columns = pd.json_normalize(json)
new_columns
# Out:
#             name  id           family             order         genus  \
# 0      Persimmon  52        Ebenaceae           Rosales     Diospyros
# 1     Strawberry   3         Rosaceae           Rosales      Fragaria
# 2         Banana   1         Musaceae      Zingiberales          Musa
# 3         Tomato   5       Solanaceae         Solanales       Solanum
# 4           Pear   4         Rosaceae           Rosales         Pyrus
# 5         Durian  60        Malvaceae          Malvales         Durio
# 6     Blackberry  64         Rosaceae           Rosales         Rubus
# 7    Lingonberry  65        Ericaceae          Ericales     Vaccinium
# 8           Kiwi  66    Actinidiaceae  Struthioniformes       Apteryx
# 9         Lychee  67      Sapindaceae        Sapindales        Litchi
# 10     Pineapple  10     Bromeliaceae            Poales        Ananas
# 11           Fig  68         Moraceae           Rosales         Ficus
# ...

# %%
#df = pd.concat([df, new_columns], axis=1)

# %%
df = df.drop('nutritions', axis=1)

# %%
df[df['nutritions.calories'] < 30]
# Out:
#           name  id    family       order     genus  nutritions.calories  \
# 1   Strawberry   3  Rosaceae     Rosales  Fragaria                   29
# 16  GreenApple  72  Rosaceae     Rosales     Malus                   21
# 19       Lemon  26  Rutaceae  Sapindales    Citrus                   29
# 21   Blueberry  33  Rosaceae     Rosales  Fragaria                   29
# 24     Apricot  35  Rosaceae     Rosales    Prunus                   15
# 29        Lime  44  Rutaceae  Sapindales    Citrus                   25
#
#     nutritions.fat  nutritions.sugar  nutritions.carbohydrates  \
# 1              0.4               5.4                       5.5
# 16             0.1               6.4                       3.1
# 19             0.3               2.5                       9.0
# 21             0.4               5.4                       5.5
# 24             0.1               3.2                       3.9
# 29             0.1               1.7                       8.4
#
# ...

# %%
df[df['nutritions.sugar'] < 3].sort_values('nutritions.sugar',ascending = True)
# Out:
#           name  id           family         order    genus  \
# 12  Gooseberry  69  Grossulariaceae  Saxifragales    Ribes
# 35     Avocado  84        Lauraceae      Laurales   Persea
# 25      Papaya  42       Caricaceae     Caricacea   Carica
# 29        Lime  44         Rutaceae    Sapindales   Citrus
# 19       Lemon  26         Rutaceae    Sapindales   Citrus
# 3       Tomato   5       Solanaceae     Solanales  Solanum
#
#     nutritions.calories  nutritions.fat  nutritions.sugar  \
# 12                   44            0.60              0.00
# 35                  160           14.66              0.66
# 25                   43            0.40              1.00
# 29                   25            0.10              1.70
# 19                   29            0.30              2.50
# 3                    74            0.20              2.60
#
#     nutritions.carbohydrates  nutritions.protein
# 12                     10.00                 0.9
# ...

# %%
df.sort_values('name',ascending = True).head()
# Out:
#           name  id     family         order   genus  nutritions.calories  \
# 22       Apple   6   Rosaceae       Rosales   Malus                   52
# 24     Apricot  35   Rosaceae       Rosales  Prunus                   15
# 35     Avocado  84  Lauraceae      Laurales  Persea                  160
# 2       Banana   1   Musaceae  Zingiberales    Musa                   96
# 6   Blackberry  64   Rosaceae       Rosales   Rubus                   40
#
#     nutritions.fat  nutritions.sugar  nutritions.carbohydrates  \
# 22            0.40             10.30                     11.40
# 24            0.10              3.20                      3.90
# 35           14.66              0.66                      8.53
# 2             0.20             17.20                     22.00
# 6             0.40              4.50                      9.00
#
#     nutritions.protein
# 22                 0.3
# 24                 0.5
# 35                 2.0
# 2                  1.0
# 6                  1.3
